# %%
import pandas as pd
import matplotlib.pyplot as plt

read_df = pd.read_csv("filtered.csv")

# %%
# Plotting
plt.figure(figsize=(8, 5))
plt.scatter(read_df['Blocks'], read_df['BlocksRecoveredPct'], color='skyblue')
plt.axvline(x=82, color="red", linestyle="--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
